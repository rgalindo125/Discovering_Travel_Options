# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
import json
from tqdm import tqdm_notebook

# %%
#Country = ["US"]
#currency = ["USD"]
#Language: locale = ["en-US"]
# End date: inboundpartialdate = ["2019-12-30"]

base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/"

headers={"X-RapidAPI-Host": "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "077cfd7813mshfe97bf766bd036dp106fd9jsneb6caf492da9"}

originplace = ["SFO-sky", "ATL-sky","LAX-sky"]
destinationplace = ["ORD-sky"]
outboundpartialdate = ["2019-08-01"]


query_url = base_url + originplace [0] + "/" + destinationplace[0] + "/" + outboundpartialdate[0] + "?inboundpartialdate=2019-12-30"

response = requests.get(query_url, headers=headers).json()

#response = requests.get(base_url/{originplace}/{destinationplace}/{outboundpartialdate}, headers=headers).json()

print(query_url)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2019-08-01?inboundpartialdate=2019-12-30
# {
#     "Carriers": [
#         {
#             "CarrierId": 833,
#             "Name": "American Airlines"
#         },
#         {
#             "CarrierId": 851,
#             "Name": "Alaska Airlines"
#         },
#         {
#             "CarrierId": 1065,
#             "Name": "Frontier Airlines"
#         },
#         {
#             "CarrierId": 1721,
#             "Name": "Sun Country Airlines"
#         },
#         {
#             "CarrierId": 1793,
#             "Name": "United"
#         }
#     ],
#     "Currencies": [
#         {
#             "Code": "USD",
#             "DecimalDigits": 2,
#             "DecimalSeparator": ".",
#             "RoundingCoefficient": 0,
#             "SpaceBetweenAmountAndSymbol": false,
#             "Symbol": "$",
#             "SymbolOnLeft": true,
#             "ThousandsSeparator": ","
#         }
#     ],
#     "Places": [
#         {
#             "CityId": "CHIA",
#             "CityName": "Chicago",
#             "CountryName": "United States",
#             "IataCode": "ORD",
#             "Name": "Chicago O'Hare International",
#             "PlaceId": 73076,
#             "SkyscannerCode": "ORD",
#             "Type": "Station"
#         },
#         {
#             "CityId": "SFOA",
#             "CityName": "San Francisco",
#             "CountryName": "United States",
#             "IataCode": "SFO",
#             "Name": "San Francisco International",
#             "PlaceId": 81727,
#             "SkyscannerCode": "SFO",
#             "Type": "Station"
#         }
#     ],
#     "Quotes": [
#         {
#             "Direct": false,
#             "MinPrice": 145.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-01T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T04:50:00",
#             "QuoteId": 1
#         },
#         {
#             "Direct": true,
#             "MinPrice": 284.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-08-01T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T03:26:00",
#             "QuoteId": 2
#         },
#         {
#             "Direct": false,
#             "MinPrice": 184.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-02T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T06:08:00",
#             "QuoteId": 3
#         },
#         {
#             "Direct": true,
#             "MinPrice": 284.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-08-02T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T03:23:00",
#             "QuoteId": 4
#         },
#         {
#             "Direct": false,
#             "MinPrice": 158.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-03T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T03:37:00",
#             "QuoteId": 5
#         },
#         {
#             "Direct": true,
#             "MinPrice": 214.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-03T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T14:44:00",
#             "QuoteId": 6
#         },
#         {
#             "Direct": false,
#             "MinPrice": 168.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-04T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T06:13:00",
#             "QuoteId": 7
#         },
#         {
#             "Direct": true,
#             "MinPrice": 214.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-04T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T06:18:00",
#             "QuoteId": 8
#         },
#         {
#             "Direct": false,
#             "MinPrice": 145.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-05T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T16:32:00",
#             "QuoteId": 9
#         },
#         {
#             "Direct": true,
#             "MinPrice": 214.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-05T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T19:07:00",
#             "QuoteId": 10
#         },
#         {
#             "Direct": false,
#             "MinPrice": 140.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-06T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T08:40:00",
#             "QuoteId": 11
#         },
#         {
#             "Direct": true,
#             "MinPrice": 214.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-06T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T06:09:00",
#             "QuoteId": 12
#         },
#         {
#             "Direct": false,
#             "MinPrice": 145.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-07T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T16:04:00",
#             "QuoteId": 13
#         },
#         {
#             "Direct": true,
#             "MinPrice": 214.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-07T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T02:26:00",
#             "QuoteId": 14
#         },
#         {
#             "Direct": false,
#             "MinPrice": 145.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-08T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T05:24:00",
#             "QuoteId": 15
#         },
#         {
#             "Direct": true,
#             "MinPrice": 214.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-08T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T01:10:00",
#             "QuoteId": 16
#         },
#         {
#             "Direct": false,
#             "MinPrice": 154.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-09T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T04:30:00",
#             "QuoteId": 17
#         },
#         {
#             "Direct": true,
#             "MinPrice": 214.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-09T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T18:25:00",
#             "QuoteId": 18
#         },
#         {
#             "Direct": false,
#             "MinPrice": 147.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-08-10T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T04:35:00",
#             "QuoteId": 19
#         },
#         {
#             "Direct": true,
#             "MinPrice": 202.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-10T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T05:25:00",
#             "QuoteId": 20
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-08-11T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T04:30:00",
#             "QuoteId": 21
#         },
#         {
#             "Direct": false,
#             "MinPrice": 133.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-12T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T03:57:00",
#             "QuoteId": 22
#         },
#         {
#             "Direct": true,
#             "MinPrice": 202.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-12T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T18:02:00",
#             "QuoteId": 23
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-13T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T23:01:00",
#             "QuoteId": 24
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-13T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T04:27:00",
#             "QuoteId": 25
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-14T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T02:53:00",
#             "QuoteId": 26
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-14T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T02:53:00",
#             "QuoteId": 27
#         },
#         {
#             "Direct": false,
#             "MinPrice": 118.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-15T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T10:33:00",
#             "QuoteId": 28
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-08-15T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T22:48:00",
#             "QuoteId": 29
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-16T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T02:28:00",
#             "QuoteId": 30
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-17T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T07:39:00",
#             "QuoteId": 31
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-17T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T07:39:00",
#             "QuoteId": 32
#         },
#         {
#             "Direct": false,
#             "MinPrice": 123.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-18T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T20:27:00",
#             "QuoteId": 33
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-08-18T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T20:41:00",
#             "QuoteId": 34
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-19T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T00:07:00",
#             "QuoteId": 35
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-19T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T00:07:00",
#             "QuoteId": 36
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-20T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T18:18:00",
#             "QuoteId": 37
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-20T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T20:13:00",
#             "QuoteId": 38
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-21T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T18:45:00",
#             "QuoteId": 39
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-21T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T18:45:00",
#             "QuoteId": 40
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-22T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T00:18:00",
#             "QuoteId": 41
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-22T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T08:52:00",
#             "QuoteId": 42
#         },
#         {
#             "Direct": false,
#             "MinPrice": 123.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-23T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T05:05:00",
#             "QuoteId": 43
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-23T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T04:55:00",
#             "QuoteId": 44
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-24T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T23:03:00",
#             "QuoteId": 45
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-24T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T02:38:00",
#             "QuoteId": 46
#         },
#         {
#             "Direct": false,
#             "MinPrice": 123.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-25T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T15:41:00",
#             "QuoteId": 47
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-25T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T07:44:00",
#             "QuoteId": 48
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-26T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T00:43:00",
#             "QuoteId": 49
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-26T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-17T11:14:00",
#             "QuoteId": 50
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-27T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T14:16:00",
#             "QuoteId": 51
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-27T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-17T02:57:00",
#             "QuoteId": 52
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-28T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T20:47:00",
#             "QuoteId": 53
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-28T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T20:47:00",
#             "QuoteId": 54
#         },
#         {
#             "Direct": false,
#             "MinPrice": 130.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-08-29T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T06:39:00",
#             "QuoteId": 55
#         },
#         {
#             "Direct": true,
#             "MinPrice": 194.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-08-29T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T03:55:00",
#             "QuoteId": 56
#         },
#         {
#             "Direct": false,
#             "MinPrice": 186.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1721
#                 ],
#                 "DepartureDate": "2019-08-30T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T23:02:00",
#             "QuoteId": 57
#         },
#         {
#             "Direct": true,
#             "MinPrice": 194.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-08-30T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T02:06:00",
#             "QuoteId": 58
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-08-31T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T20:33:00",
#             "QuoteId": 59
#         }
#     ],
#     "Routes": []
# }

# %%
carrier=[]
price=[]
#originplace=[]
destinationplace=[]

count = 1

for orgin in tqdm_notebook(originplace):
    
    try:
         
        
        response = requests.get(query_url, headers=headers).json()
    
        carrier.append(response["Carriers"][0]["Name"]) #I selected the first index as an example. This need to loop thru
        price.append(response["Quotes"][0]["MinPrice"]) #I selected the first index as an example. This need to loop thru
        #originplace.append(response["Places"][1]["IataCode"])
        destinationplace.append(response["Places"][0]["IataCode"])
        
        count = count + 1
        
    except:
        print("not working")
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))

# %%
print(carrier)
print(price)
print(originplace)
print(destinationplace)
# Out:
# ['American Airlines', 'American Airlines', 'American Airlines']
# [145.0, 145.0, 145.0]
# ['SFO-sky', 'ATL-sky', 'LAX-sky']
# ['ORD', 'ORD', 'ORD']

# %%
d={"From":originplace}
prices_df=pd.DataFrame(d)
prices_df["From"]=originplace
prices_df["To"]=destinationplace
prices_df["Carrier"]=carrier
prices_df["Price"]=price

prices_df
# Out:
#       From   To            Carrier  Price
# 0  SFO-sky  ORD  American Airlines  145.0
# 1  ATL-sky  ORD  American Airlines  145.0
# 2  LAX-sky  ORD  American Airlines  145.0
