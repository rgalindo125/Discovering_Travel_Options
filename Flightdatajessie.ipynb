# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
import json
from tqdm import tqdm_notebook

# %%
#Country = ["US"]
#currency = ["USD"]
#Language: locale = ["en-US"]
# End date: inboundpartialdate = ["2019-12-30"]

base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/"

headers={"X-RapidAPI-Host": "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "077cfd7813mshfe97bf766bd036dp106fd9jsneb6caf492da9"}

originplace = ["SFO-sky", "JFK-sky"]
destinationplace = ["ORD-sky", "ATL-sky","LAX-sky"]
outboundpartialdate = ["2019-08-01"]


query_url = base_url + originplace [0] + "/" + destinationplace[0] + "/" + outboundpartialdate[0] + "?inboundpartialdate=2019-12-30"

response = requests.get(query_url, headers=headers).json()

#response = requests.get(base_url/{originplace}/{destinationplace}/{outboundpartialdate}, headers=headers).json()

print(query_url)
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2019-08-01?inboundpartialdate=2019-12-30
# {
#     "Carriers": [
#         {
#             "CarrierId": 833,
#             "Name": "American Airlines"
#         },
#         {
#             "CarrierId": 851,
#             "Name": "Alaska Airlines"
#         },
#         {
#             "CarrierId": 1065,
#             "Name": "Frontier Airlines"
#         },
#         {
#             "CarrierId": 1721,
#             "Name": "Sun Country Airlines"
#         },
#         {
#             "CarrierId": 1793,
#             "Name": "United"
#         }
#     ],
#     "Currencies": [
#         {
#             "Code": "USD",
#             "DecimalDigits": 2,
#             "DecimalSeparator": ".",
#             "RoundingCoefficient": 0,
#             "SpaceBetweenAmountAndSymbol": false,
#             "Symbol": "$",
#             "SymbolOnLeft": true,
# ...

# %%
response["Quotes"]
# Out:
# [{'QuoteId': 1,
#   'MinPrice': 169.0,
#   'Direct': False,
#   'OutboundLeg': {'CarrierIds': [1065],
#    'OriginId': 81727,
#    'DestinationId': 73076,
#    'DepartureDate': '2019-08-01T00:00:00'},
#   'QuoteDateTime': '2019-07-22T17:16:00'},
#  {'QuoteId': 2,
#   'MinPrice': 284.0,
#   'Direct': True,
#   'OutboundLeg': {'CarrierIds': [1793],
#    'OriginId': 81727,
#    'DestinationId': 73076,
#    'DepartureDate': '2019-08-01T00:00:00'},
#   'QuoteDateTime': '2019-07-22T14:01:00'},
#  {'QuoteId': 3,
#   'MinPrice': 199.0,
#   'Direct': False,
#   'OutboundLeg': {'CarrierIds': [1065],
#    'OriginId': 81727,
#    'DestinationId': 73076,
#    'DepartureDate': '2019-08-02T00:00:00'},
#   'QuoteDateTime': '2019-07-22T23:03:00'},
#  {'QuoteId': 4,
#   'MinPrice': 282.0,
#   'Direct': True,
#   'OutboundLeg': {'CarrierIds': [851],
#    'OriginId': 81727,
#    'DestinationId': 73076,
#    'DepartureDate': '2019-08-02T00:00:00'},
#   'QuoteDateTime': '2019-07-22T03:14:00'},
# ...

# %%
price=[]
destinationplace=[]

count = 1

for orgin in tqdm_notebook(originplace):
    
          
        
        response = requests.get(query_url, headers=headers).json()
        
        for price in response["Quotes"]:
        
            price.append(response["Quotes"]["MinPrice"])
# Out:
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-1b26950482a7> in <module>
#      13         for price in response["Quotes"]:
#      14
# ---> 15             price.append(response["Quotes"]["MinPrice"])
#      16
#      17
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
print(carrier)
print(price)
print(originplace)
print(destinationplace)
# Out:
# ['American Airlines']
# [145.0]
# ['SFO-sky']
# ['ORD']

# %%
d={"From":originplace}
prices_df=pd.DataFrame(d)
prices_df["From"]=originplace
prices_df["To"]=destinationplace
prices_df["Carrier"]=carrier
prices_df["Price"]=price

prices_df
# Out:
#       From   To          Carrier  Price
# 0  SFO-sky  ORD  Alaska Airlines  145.0
