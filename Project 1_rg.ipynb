# %%
# Destinations
import pandas as pd
import json
import requests

url ="https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2019-09-01?inboundpartialdate=2019-12-01"

response = requests.get(url,
 headers={"X-RapidAPI-Host": "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
   "X-RapidAPI-Key": "077cfd7813mshfe97bf766bd036dp106fd9jsneb6caf492da9"}).json()


print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "Carriers": [
#         {
#             "CarrierId": 833,
#             "Name": "American Airlines"
#         },
#         {
#             "CarrierId": 851,
#             "Name": "Alaska Airlines"
#         },
#         {
#             "CarrierId": 1065,
#             "Name": "Frontier Airlines"
#         },
#         {
#             "CarrierId": 1793,
#             "Name": "United"
#         }
#     ],
#     "Currencies": [
#         {
#             "Code": "USD",
#             "DecimalDigits": 2,
#             "DecimalSeparator": ".",
#             "RoundingCoefficient": 0,
#             "SpaceBetweenAmountAndSymbol": false,
#             "Symbol": "$",
#             "SymbolOnLeft": true,
#             "ThousandsSeparator": ","
#         }
#     ],
#     "Places": [
#         {
#             "CityId": "CHIA",
#             "CityName": "Chicago",
#             "CountryName": "United States",
#             "IataCode": "ORD",
#             "Name": "Chicago O'Hare International",
#             "PlaceId": 73076,
#             "SkyscannerCode": "ORD",
#             "Type": "Station"
#         },
#         {
#             "CityId": "SFOA",
#             "CityName": "San Francisco",
#             "CountryName": "United States",
#             "IataCode": "SFO",
#             "Name": "San Francisco International",
#             "PlaceId": 81727,
#             "SkyscannerCode": "SFO",
#             "Type": "Station"
#         }
#     ],
#     "Quotes": [
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-01T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T16:23:00",
#             "QuoteId": 1
#         },
#         {
#             "Direct": false,
#             "MinPrice": 130.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-02T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T17:34:00",
#             "QuoteId": 2
#         },
#         {
#             "Direct": true,
#             "MinPrice": 174.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-02T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T15:00:00",
#             "QuoteId": 3
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-03T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T20:36:00",
#             "QuoteId": 4
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-03T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T20:36:00",
#             "QuoteId": 5
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-04T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T02:20:00",
#             "QuoteId": 6
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-04T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-17T02:53:00",
#             "QuoteId": 7
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-05T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T06:44:00",
#             "QuoteId": 8
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-05T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T06:44:00",
#             "QuoteId": 9
#         },
#         {
#             "Direct": false,
#             "MinPrice": 128.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-06T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-18T21:29:00",
#             "QuoteId": 10
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-06T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T06:43:00",
#             "QuoteId": 11
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-07T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-17T04:22:00",
#             "QuoteId": 12
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-07T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-12T19:14:00",
#             "QuoteId": 13
#         },
#         {
#             "Direct": false,
#             "MinPrice": 123.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-08T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T22:51:00",
#             "QuoteId": 14
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-09-08T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T22:51:00",
#             "QuoteId": 15
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-09T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T16:23:00",
#             "QuoteId": 16
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-09T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T03:26:00",
#             "QuoteId": 17
#         },
#         {
#             "Direct": false,
#             "MinPrice": 128.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-10T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T01:52:00",
#             "QuoteId": 18
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-10T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T23:18:00",
#             "QuoteId": 19
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-11T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T12:01:00",
#             "QuoteId": 20
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-11T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T16:05:00",
#             "QuoteId": 21
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-12T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T12:23:00",
#             "QuoteId": 22
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-12T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T12:23:00",
#             "QuoteId": 23
#         },
#         {
#             "Direct": false,
#             "MinPrice": 128.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-13T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T12:40:00",
#             "QuoteId": 24
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-13T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T02:32:00",
#             "QuoteId": 25
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-14T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T11:48:00",
#             "QuoteId": 26
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-14T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T11:49:00",
#             "QuoteId": 27
#         },
#         {
#             "Direct": false,
#             "MinPrice": 128.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-15T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T20:21:00",
#             "QuoteId": 28
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-15T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T08:42:00",
#             "QuoteId": 29
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-16T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T17:33:00",
#             "QuoteId": 30
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-16T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-18T19:51:00",
#             "QuoteId": 31
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-17T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T13:45:00",
#             "QuoteId": 32
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-17T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-14T06:24:00",
#             "QuoteId": 33
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-18T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T13:55:00",
#             "QuoteId": 34
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-18T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-14T04:57:00",
#             "QuoteId": 35
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-19T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T17:17:00",
#             "QuoteId": 36
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-19T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T01:17:00",
#             "QuoteId": 37
#         },
#         {
#             "Direct": false,
#             "MinPrice": 128.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-20T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T02:31:00",
#             "QuoteId": 38
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-20T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T02:32:00",
#             "QuoteId": 39
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-21T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T13:57:00",
#             "QuoteId": 40
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-21T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-16T11:48:00",
#             "QuoteId": 41
#         },
#         {
#             "Direct": false,
#             "MinPrice": 128.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-22T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T09:05:00",
#             "QuoteId": 42
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-22T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T16:33:00",
#             "QuoteId": 43
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-23T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T19:58:00",
#             "QuoteId": 44
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-23T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T15:46:00",
#             "QuoteId": 45
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-24T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T22:48:00",
#             "QuoteId": 46
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-24T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T11:54:00",
#             "QuoteId": 47
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-25T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T13:53:00",
#             "QuoteId": 48
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-25T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-16T03:38:00",
#             "QuoteId": 49
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-26T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T16:23:00",
#             "QuoteId": 50
#         },
#         {
#             "Direct": true,
#             "MinPrice": 154.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-09-26T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T13:20:00",
#             "QuoteId": 51
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-09-27T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T13:53:00",
#             "QuoteId": 52
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-28T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T13:54:00",
#             "QuoteId": 53
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-28T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T13:54:00",
#             "QuoteId": 54
#         },
#         {
#             "Direct": false,
#             "MinPrice": 128.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-29T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-18T21:34:00",
#             "QuoteId": 55
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-29T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T20:22:00",
#             "QuoteId": 56
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-30T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T10:14:00",
#             "QuoteId": 57
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-30T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-20T01:20:00",
#             "QuoteId": 58
#         }
#     ],
#     "Routes": []
# }

# %%
country = ["US"]
currency = ["USD"]
locale = ["en-US"]
originplace = ["SFO", "ATL"]
destinationplace = ["ORD","LAX"]
outboundpartialdate = ["2019-08-01"]
inboundpartialdate = ["2019-12-30"]


#for orgin in originplace:

base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/"
query_url = url + country[0] + "/" + currency[0] + "/" + locale[0] + "/" + originplace[1] + "-sky/" + destinationplace[1] + "-sky/" + outboundpartialdate[0] + "?inboundpartialdate=2019-12-30"

print(query_url)
# Out:
# https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2019-09-01?inboundpartialdate=2019-12-01US/USD/en-US/ATL-sky/LAX-sky/2019-08-01?inboundpartialdate=2019-12-30
