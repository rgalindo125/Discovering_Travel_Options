# %%
# Destinations
import pandas as pd
import json
import requests

url ="https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2019-09-01?inboundpartialdate=2019-12-01"

response = requests.get(url,
 headers={"X-RapidAPI-Host": "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
   "X-RapidAPI-Key": "077cfd7813mshfe97bf766bd036dp106fd9jsneb6caf492da9"}).json()


print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "Carriers": [
#         {
#             "CarrierId": 833,
#             "Name": "American Airlines"
#         },
#         {
#             "CarrierId": 851,
#             "Name": "Alaska Airlines"
#         },
#         {
#             "CarrierId": 1065,
#             "Name": "Frontier Airlines"
#         },
#         {
#             "CarrierId": 1793,
#             "Name": "United"
#         }
#     ],
#     "Currencies": [
#         {
#             "Code": "USD",
#             "DecimalDigits": 2,
#             "DecimalSeparator": ".",
#             "RoundingCoefficient": 0,
#             "SpaceBetweenAmountAndSymbol": false,
#             "Symbol": "$",
#             "SymbolOnLeft": true,
#             "ThousandsSeparator": ","
#         }
#     ],
#     "Places": [
#         {
#             "CityId": "CHIA",
#             "CityName": "Chicago",
#             "CountryName": "United States",
#             "IataCode": "ORD",
#             "Name": "Chicago O'Hare International",
#             "PlaceId": 73076,
#             "SkyscannerCode": "ORD",
#             "Type": "Station"
#         },
#         {
#             "CityId": "SFOA",
#             "CityName": "San Francisco",
#             "CountryName": "United States",
#             "IataCode": "SFO",
#             "Name": "San Francisco International",
#             "PlaceId": 81727,
#             "SkyscannerCode": "SFO",
#             "Type": "Station"
#         }
#     ],
#     "Quotes": [
#         {
#             "Direct": false,
#             "MinPrice": 147.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-09-01T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T16:19:00",
#             "QuoteId": 1
#         },
#         {
#             "Direct": true,
#             "MinPrice": 157.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-01T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T23:00:00",
#             "QuoteId": 2
#         },
#         {
#             "Direct": false,
#             "MinPrice": 124.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-02T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T22:09:00",
#             "QuoteId": 3
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-02T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T20:58:00",
#             "QuoteId": 4
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-03T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T15:13:00",
#             "QuoteId": 5
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-03T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T19:59:00",
#             "QuoteId": 6
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-04T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T17:31:00",
#             "QuoteId": 7
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-04T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-22T18:02:00",
#             "QuoteId": 8
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-05T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T14:18:00",
#             "QuoteId": 9
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-05T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T03:43:00",
#             "QuoteId": 10
#         },
#         {
#             "Direct": false,
#             "MinPrice": 125.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-06T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T20:16:00",
#             "QuoteId": 11
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-06T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T12:44:00",
#             "QuoteId": 12
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-07T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T22:00:00",
#             "QuoteId": 13
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-07T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-22T19:32:00",
#             "QuoteId": 14
#         },
#         {
#             "Direct": false,
#             "MinPrice": 123.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-08T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T15:45:00",
#             "QuoteId": 15
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-08T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T13:57:00",
#             "QuoteId": 16
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-09T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T12:39:00",
#             "QuoteId": 17
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-09T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-23T16:34:00",
#             "QuoteId": 18
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-10T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T19:12:00",
#             "QuoteId": 19
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-11T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T15:54:00",
#             "QuoteId": 20
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-11T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T15:54:00",
#             "QuoteId": 21
#         },
#         {
#             "Direct": false,
#             "MinPrice": 114.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-12T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T17:29:00",
#             "QuoteId": 22
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-12T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-19T14:21:00",
#             "QuoteId": 23
#         },
#         {
#             "Direct": false,
#             "MinPrice": 106.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-13T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T12:54:00",
#             "QuoteId": 24
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-13T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T12:54:00",
#             "QuoteId": 25
#         },
#         {
#             "Direct": false,
#             "MinPrice": 109.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-14T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T02:56:00",
#             "QuoteId": 26
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-14T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T02:56:00",
#             "QuoteId": 27
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-09-15T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T13:55:00",
#             "QuoteId": 28
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-16T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T18:15:00",
#             "QuoteId": 29
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-16T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T14:13:00",
#             "QuoteId": 30
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-17T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T23:58:00",
#             "QuoteId": 31
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-17T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T05:24:00",
#             "QuoteId": 32
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-18T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T22:01:00",
#             "QuoteId": 33
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-18T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T02:56:00",
#             "QuoteId": 34
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-19T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T09:20:00",
#             "QuoteId": 35
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-19T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T15:02:00",
#             "QuoteId": 36
#         },
#         {
#             "Direct": false,
#             "MinPrice": 106.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-20T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T21:49:00",
#             "QuoteId": 37
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-20T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T14:28:00",
#             "QuoteId": 38
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-21T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T20:16:00",
#             "QuoteId": 39
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-09-21T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T20:16:00",
#             "QuoteId": 40
#         },
#         {
#             "Direct": false,
#             "MinPrice": 123.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-22T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T08:51:00",
#             "QuoteId": 41
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-22T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T15:03:00",
#             "QuoteId": 42
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-23T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T18:33:00",
#             "QuoteId": 43
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-23T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T15:58:00",
#             "QuoteId": 44
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-24T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T20:16:00",
#             "QuoteId": 45
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-24T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T15:59:00",
#             "QuoteId": 46
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-25T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T22:12:00",
#             "QuoteId": 47
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-25T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-24T13:54:00",
#             "QuoteId": 48
#         },
#         {
#             "Direct": false,
#             "MinPrice": 108.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-26T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T12:55:00",
#             "QuoteId": 49
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     833
#                 ],
#                 "DepartureDate": "2019-09-26T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T19:28:00",
#             "QuoteId": 50
#         },
#         {
#             "Direct": false,
#             "MinPrice": 107.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-27T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T22:25:00",
#             "QuoteId": 51
#         },
#         {
#             "Direct": true,
#             "MinPrice": 139.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1793
#                 ],
#                 "DepartureDate": "2019-09-27T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T20:16:00",
#             "QuoteId": 52
#         },
#         {
#             "Direct": false,
#             "MinPrice": 113.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-28T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-23T18:08:00",
#             "QuoteId": 53
#         },
#         {
#             "Direct": true,
#             "MinPrice": 136.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-28T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-21T12:16:00",
#             "QuoteId": 54
#         },
#         {
#             "Direct": false,
#             "MinPrice": 134.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-29T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T12:55:00",
#             "QuoteId": 55
#         },
#         {
#             "Direct": true,
#             "MinPrice": 157.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-29T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T12:55:00",
#             "QuoteId": 56
#         },
#         {
#             "Direct": false,
#             "MinPrice": 103.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     1065
#                 ],
#                 "DepartureDate": "2019-09-30T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T14:17:00",
#             "QuoteId": 57
#         },
#         {
#             "Direct": true,
#             "MinPrice": 137.0,
#             "OutboundLeg": {
#                 "CarrierIds": [
#                     851
#                 ],
#                 "DepartureDate": "2019-09-30T00:00:00",
#                 "DestinationId": 73076,
#                 "OriginId": 81727
#             },
#             "QuoteDateTime": "2019-07-25T19:26:00",
#             "QuoteId": 58
#         }
#     ],
#     "Routes": []
# }

# %%
country = ["US"]
currency = ["USD"]
locale = ["en-US"]
originplace = ["SFO", "ATL"]
destinationplace = ["ORD","LAX"]
outboundpartialdate = ["2019-08-01"]
inboundpartialdate = ["2019-12-30"]


#for orgin in originplace:

base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/"
query_url = url + country[0] + "/" + currency[0] + "/" + locale[0] + "/" + originplace[1] + "-sky/" + destinationplace[1] + "-sky/" + outboundpartialdate[0] + "?inboundpartialdate=2019-12-30"

print(query_url)
# Out:
# https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/SFO-sky/ORD-sky/2019-09-01?inboundpartialdate=2019-12-01US/USD/en-US/ATL-sky/LAX-sky/2019-08-01?inboundpartialdate=2019-12-30
