# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
import json
import operator
from tqdm import tqdm_notebook as tqdm

# %%
outbound_data = "Resources/outbound_data.csv"
#cities_df = pd.read_csv(csv_path)
outbound_data_df = pd.read_csv(outbound_data,encoding="utf-8")
outbound_data_df.head()

most_visited_destination = "Resources/most_visited_destination_data.csv"
most_visited_cities_df = pd.read_csv(most_visited_destination,encoding="utf-8")
#len(most_visited_cities_df)
outbound_airport_code_tolist = outbound_data_df['Airport Code'].tolist()
#outbound_airport_code_tolist
most_visited_cities_airport_list = most_visited_cities_df['Airport Code'].tolist()

# %%
# Routes Outbound - Inbound - Trying with one city and fixed dates

carriers_info = []
places_info = []
quotes_info = []

base_url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browseroutes/v1.0/US/USD/en-US/"

originplace = outbound_airport_code_tolist
destinationplace = most_visited_cities_airport_list
outboundpartialdate = ["2019-12-15"]
inboundpartialdate = ["2020-01-05"]

destination_counter = 1
#Print statement to inform when data acquisition start
print(f"Beginning Data Acquisition")
print(f"------------&&&&-------------------")

for x in tqdm(destinationplace):
    try:
        response = requests.get(base_url+outbound_airport_code_tolist[0]+"/"+x+ "/"+outboundpartialdate[0]+"?inboundpartialdate="+inboundpartialdate[0], headers=headers).json()
        carriers_info.append(response['Carriers'])
        places_info.append(response['Places'])
        quotes_info.append(response['Quotes'])
        
        print(f"Data Acquisition {destination_counter} | Outbound City: {outbound_airport_code_tolist[0]}")  
        
        destination_counter = destination_counter + 1
    except:
        print("Route not found...!!")
    continue
    
# Print statement to inform when all records have been acquired.
print(f"------------&&&&---------------")
print(f"Data Acquisition Complete")
print(f"------------&&&&---------------")
        
        
      
        
        #response = requests.get(query_url, headers=headers).json()

#response = requests.get(base_url/{originplace}/{destinationplace}/{outboundpartialdate}, headers=headers).json()
# Out:
# Beginning Data Acquisition
# ------------&&&&-------------------
# HBox(children=(IntProgress(value=0, max=68), HTML(value='')))
# Data Acquisition 1 | Outbound City: IAH-sky
# Data Acquisition 2 | Outbound City: IAH-sky
# Data Acquisition 3 | Outbound City: IAH-sky
# Data Acquisition 4 | Outbound City: IAH-sky
# Data Acquisition 5 | Outbound City: IAH-sky
# Data Acquisition 6 | Outbound City: IAH-sky
# Data Acquisition 7 | Outbound City: IAH-sky
# Data Acquisition 8 | Outbound City: IAH-sky
# Data Acquisition 9 | Outbound City: IAH-sky
# Data Acquisition 10 | Outbound City: IAH-sky
# Data Acquisition 11 | Outbound City: IAH-sky
# Data Acquisition 12 | Outbound City: IAH-sky
# Data Acquisition 13 | Outbound City: IAH-sky
# Data Acquisition 14 | Outbound City: IAH-sky
# Data Acquisition 15 | Outbound City: IAH-sky
# Data Acquisition 16 | Outbound City: IAH-sky
# Data Acquisition 17 | Outbound City: IAH-sky
# Data Acquisition 18 | Outbound City: IAH-sky
# Data Acquisition 19 | Outbound City: IAH-sky
# Data Acquisition 20 | Outbound City: IAH-sky
# Data Acquisition 21 | Outbound City: IAH-sky
# Data Acquisition 22 | Outbound City: IAH-sky
# Data Acquisition 23 | Outbound City: IAH-sky
# Data Acquisition 24 | Outbound City: IAH-sky
# Data Acquisition 25 | Outbound City: IAH-sky
# Data Acquisition 26 | Outbound City: IAH-sky
# Data Acquisition 27 | Outbound City: IAH-sky
# Data Acquisition 28 | Outbound City: IAH-sky
# Data Acquisition 29 | Outbound City: IAH-sky
# Data Acquisition 30 | Outbound City: IAH-sky
# Data Acquisition 31 | Outbound City: IAH-sky
# Data Acquisition 32 | Outbound City: IAH-sky
# Data Acquisition 33 | Outbound City: IAH-sky
# Data Acquisition 34 | Outbound City: IAH-sky
# Data Acquisition 35 | Outbound City: IAH-sky
# Data Acquisition 36 | Outbound City: IAH-sky
# Data Acquisition 37 | Outbound City: IAH-sky
# Data Acquisition 38 | Outbound City: IAH-sky
# Data Acquisition 39 | Outbound City: IAH-sky
# Data Acquisition 40 | Outbound City: IAH-sky
# Data Acquisition 41 | Outbound City: IAH-sky
# Data Acquisition 42 | Outbound City: IAH-sky
# Data Acquisition 43 | Outbound City: IAH-sky
# Data Acquisition 44 | Outbound City: IAH-sky
# Data Acquisition 45 | Outbound City: IAH-sky
# Data Acquisition 46 | Outbound City: IAH-sky
# Data Acquisition 47 | Outbound City: IAH-sky
# Data Acquisition 48 | Outbound City: IAH-sky
# Data Acquisition 49 | Outbound City: IAH-sky
# Data Acquisition 50 | Outbound City: IAH-sky
# Data Acquisition 51 | Outbound City: IAH-sky
# Data Acquisition 52 | Outbound City: IAH-sky
# Data Acquisition 53 | Outbound City: IAH-sky
# Data Acquisition 54 | Outbound City: IAH-sky
# Data Acquisition 55 | Outbound City: IAH-sky
# Data Acquisition 56 | Outbound City: IAH-sky
# Data Acquisition 57 | Outbound City: IAH-sky
# Data Acquisition 58 | Outbound City: IAH-sky
# Data Acquisition 59 | Outbound City: IAH-sky
# Data Acquisition 60 | Outbound City: IAH-sky
# Data Acquisition 61 | Outbound City: IAH-sky
# Data Acquisition 62 | Outbound City: IAH-sky
# Data Acquisition 63 | Outbound City: IAH-sky
# Data Acquisition 64 | Outbound City: IAH-sky
# Data Acquisition 65 | Outbound City: IAH-sky
# Data Acquisition 66 | Outbound City: IAH-sky
# Data Acquisition 67 | Outbound City: IAH-sky
# Data Acquisition 68 | Outbound City: IAH-sky
#
# ------------&&&&---------------
# Data Acquisition Complete
# ------------&&&&---------------

# %%
len(quotes_info)
# Out:
# 68

# %%
carriers_info
# Out:
# [[{'CarrierId': 835, 'Name': 'Air Canada'},
#   {'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 1276, 'Name': 'Japan Airlines'},
#   {'CarrierId': 1324, 'Name': 'KLM'}],
#  [{'CarrierId': 857, 'Name': 'Finnair'},
#   {'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 952, 'Name': 'Cathay Pacific'},
#   {'CarrierId': 954, 'Name': 'China Southern'},
#   {'CarrierId': 1276, 'Name': 'Japan Airlines'},
#   {'CarrierId': 1523, 'Name': 'Austrian Airlines'},
#   {'CarrierId': 1530, 'Name': 'Asiana Airlines'},
#   {'CarrierId': 1606, 'Name': 'Qantas'},
#   {'CarrierId': 1658, 'Name': 'Royal Jordanian'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [{'CarrierId': 857, 'Name': 'Finnair'},
#   {'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1523, 'Name': 'Austrian Airlines'},
#   {'CarrierId': 1710, 'Name': 'Brussels Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 1464, 'Name': 'ANA'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [],
#  [{'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1035, 'Name': 'Emirates'},
#   {'CarrierId': 1324, 'Name': 'KLM'},
#   {'CarrierId': 1368, 'Name': 'Lufthansa'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [{'CarrierId': 838, 'Name': 'Air France'},
#   {'CarrierId': 851, 'Name': 'Alaska Airlines'},
#   {'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 1324, 'Name': 'KLM'},
#   {'CarrierId': 1368, 'Name': 'Lufthansa'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1523, 'Name': 'Austrian Airlines'},
#   {'CarrierId': 1707, 'Name': 'SAS'},
#   {'CarrierId': 1710, 'Name': 'Brussels Airlines'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [{'CarrierId': 833, 'Name': 'American Airlines'},
#   {'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'}],
#  [{'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 952, 'Name': 'Cathay Pacific'},
#   {'CarrierId': 1464, 'Name': 'ANA'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'}],
#  [{'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1710, 'Name': 'Brussels Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 1464, 'Name': 'ANA'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 851, 'Name': 'Alaska Airlines'},
#   {'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 1464, 'Name': 'ANA'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 838, 'Name': 'Air France'},
#   {'CarrierId': 1368, 'Name': 'Lufthansa'},
#   {'CarrierId': 1384, 'Name': 'SWISS'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1618, 'Name': 'Qatar Airways'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [{'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'CarrierId': 833, 'Name': 'American Airlines'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1035, 'Name': 'Emirates'},
#   {'CarrierId': 1368, 'Name': 'Lufthansa'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1707, 'Name': 'SAS'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'}],
#  [],
#  [],
#  [{'CarrierId': 833, 'Name': 'American Airlines'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'}],
#  [{'CarrierId': 857, 'Name': 'Finnair'},
#   {'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1218, 'Name': 'Iberia'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1707, 'Name': 'SAS'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'}],
#  [],
#  [{'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1033, 'Name': 'Aer Lingus'},
#   {'CarrierId': 1324, 'Name': 'KLM'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [{'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1384, 'Name': 'SWISS'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 833, 'Name': 'American Airlines'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [],
#  [],
#  [],
#  [{'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [],
#  [{'CarrierId': 835, 'Name': 'Air Canada'},
#   {'CarrierId': 851, 'Name': 'Alaska Airlines'},
#   {'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 1606, 'Name': 'Qantas'},
#   {'CarrierId': 1618, 'Name': 'Qatar Airways'},
#   {'CarrierId': 1907, 'Name': 'WestJet'}],
#  [{'CarrierId': 223, 'Name': 'Interjet'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 952, 'Name': 'Cathay Pacific'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1606, 'Name': 'Qantas'},
#   {'CarrierId': 1658, 'Name': 'Royal Jordanian'},
#   {'CarrierId': 1793, 'Name': 'United'},
#   {'CarrierId': 1907, 'Name': 'WestJet'}],
#  [{'CarrierId': 1713, 'Name': 'Singapore Airlines'}],
#  [{'CarrierId': 851, 'Name': 'Alaska Airlines'},
#   {'CarrierId': 857, 'Name': 'Finnair'},
#   {'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 1368, 'Name': 'Lufthansa'},
#   {'CarrierId': 1429, 'Name': 'China Eastern'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1523, 'Name': 'Austrian Airlines'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 223, 'Name': 'Interjet'},
#   {'CarrierId': 854, 'Name': 'Avianca (Scheduled)'},
#   {'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [],
#  [{'CarrierId': 851, 'Name': 'Alaska Airlines'},
#   {'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 1907, 'Name': 'WestJet'}],
#  [],
#  [],
#  [{'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1033, 'Name': 'Aer Lingus'},
#   {'CarrierId': 1324, 'Name': 'KLM'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [{'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [],
#  [],
#  [],
#  [{'CarrierId': 857, 'Name': 'Finnair'},
#   {'CarrierId': 952, 'Name': 'Cathay Pacific'},
#   {'CarrierId': 954, 'Name': 'China Southern'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 838, 'Name': 'Air France'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'}],
#  [],
#  [{'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 981, 'Name': 'Condor'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1707, 'Name': 'SAS'},
#   {'CarrierId': 1842, 'Name': 'Viva Aerobus'}],
#  [{'CarrierId': 857, 'Name': 'Finnair'},
#   {'CarrierId': 952, 'Name': 'Cathay Pacific'},
#   {'CarrierId': 1035, 'Name': 'Emirates'},
#   {'CarrierId': 1324, 'Name': 'KLM'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1523, 'Name': 'Austrian Airlines'},
#   {'CarrierId': 1606, 'Name': 'Qantas'},
#   {'CarrierId': 1618, 'Name': 'Qatar Airways'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 851, 'Name': 'Alaska Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'},
#   {'CarrierId': 1907, 'Name': 'WestJet'}],
#  [{'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 1618, 'Name': 'Qatar Airways'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'}],
#  [{'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 1368, 'Name': 'Lufthansa'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1482, 'Name': 'Air New Zealand'},
#   {'CarrierId': 1523, 'Name': 'Austrian Airlines'},
#   {'CarrierId': 1713, 'Name': 'Singapore Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 857, 'Name': 'Finnair'},
#   {'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 929, 'Name': 'Air China'},
#   {'CarrierId': 1755, 'Name': 'Turkish Airlines'}],
#  [{'CarrierId': 223, 'Name': 'Interjet'},
#   {'CarrierId': 836, 'Name': 'Azul Airlines'},
#   {'CarrierId': 854, 'Name': 'Avianca (Scheduled)'},
#   {'CarrierId': 941, 'Name': 'Copa'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [{'CarrierId': 223, 'Name': 'Interjet'},
#   {'CarrierId': 835, 'Name': 'Air Canada'},
#   {'CarrierId': 854, 'Name': 'Avianca (Scheduled)'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1467, 'Name': 'Spirit Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [],
#  [{'CarrierId': 210, 'Name': 'Boutique Air'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}],
#  [],
#  [{'CarrierId': 223, 'Name': 'Interjet'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1793, 'Name': 'United'},
#   {'CarrierId': 1907, 'Name': 'WestJet'}],
#  [],
#  [{'CarrierId': 838, 'Name': 'Air France'},
#   {'CarrierId': 1324, 'Name': 'KLM'}],
#  [{'CarrierId': 881, 'Name': 'British Airways'},
#   {'CarrierId': 898, 'Name': 'EVA Air'},
#   {'CarrierId': 954, 'Name': 'China Southern'}],
#  [{'CarrierId': 870, 'Name': 'jetBlue'},
#   {'CarrierId': 988, 'Name': 'Delta'},
#   {'CarrierId': 1065, 'Name': 'Frontier Airlines'},
#   {'CarrierId': 1793, 'Name': 'United'}]]

# %%
len(places_info)
# Out:
# 68

# %%
#trying a formula to get min price per quote
quotes_and_prices = ((q['MinPrice'], q) for q in response['Quotes'])
min_price, quote = min(quotes_and_prices)
min_price, quote
# Out:
# (129.0,
#  {'QuoteId': 13,
#   'MinPrice': 129.0,
#   'Direct': True,
#   'OutboundLeg': {'CarrierIds': [1793],
#    'OriginId': 58440,
#    'DestinationId': 47009,
#    'DepartureDate': '2019-12-11T00:00:00'},
#   'QuoteDateTime': '2019-07-17T23:24:00'})

# %%
#Trying a formula to get max price from quotes it is not working correctly
quotes_and_prices2 = ((q['MinPrice'], q) for q in response['Quotes'])
max_price, quote = max(quotes_and_prices2)
max_price, quote
# Out:
# (955.0,
#  {'QuoteId': 2,
#   'MinPrice': 955.0,
#   'Direct': True,
#   'OutboundLeg': {'CarrierIds': [1793],
#    'OriginId': 58440,
#    'DestinationId': 47009,
#    'DepartureDate': '2019-12-01T00:00:00'},
#   'QuoteDateTime': '2019-07-22T15:21:00'})
